# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../DATA/00-puppy.jpg")
type(img)
### hemen typıne bak
# Out:
# numpy.ndarray

# %%
plt.imshow(img,cmap = "gray")

# %%
##ders 000 da bişiler var rgba olarak gelmiyo imageları acmakla alakalı

# %% [markdown]
# ## Resize images

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_rgb.shape
# Out:
# (1300, 1950, 3)

# %%
img =cv2.resize(img_rgb,(1300,275))

# %%
plt.imshow(img)

# %% [markdown]
# ## By Ratio oransal

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img =cv2.resize(img_rgb,(0,0),img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
# Bu onemli bak alttabda açıyo gbi düşün matplotlib qt
# %matplotlib qt
plt.imshow(new_img)

# %% [markdown]
# ## Flipping images ****

# %%
# %matplotlib inline

# %%
# Along central x axis
new_img = cv2.flip(new_img,0)
plt.imshow(new_img)

# %%
# Along central y axis
new_img = cv2.flip(new_img,1)
plt.imshow(new_img)

# %% [markdown]
# ## Saving Image Files

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite("yeni-resim-yazuyorum.jpg",new_img)
# Out:
# True

# %% [markdown]
# ### Keep in mind, the above stored the BGR version of the image.

# %%
test_image = cv2.imread("yeni-resim-yazuyorum.jpg")

# %%
plt.imshow(test_image)

# %% [markdown]
# ## Larger Displays in the Notebook

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(new_img)

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(cv2.flip(new_img,0))
