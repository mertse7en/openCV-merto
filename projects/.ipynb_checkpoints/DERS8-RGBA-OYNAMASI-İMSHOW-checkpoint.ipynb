# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open("../DATA/00-puppy.jpg")

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_array = np.asarray(pic)

# %%
pic_array.shape
# Out:
# (1300, 1950, 3)

# %%
# pic_array

# %%
plt.imshow(pic_array)

# %%
pic_array.shape
# Out:
# (1300, 1950, 3)

# %% [markdown]
# ## 3 tane var red green blue 0 stands for red  , 1 stands for green , 2 stands for blue

# %%
pic_red = pic_array[: , : , 0]
pic_blue = pic_array[: , : , 1]
pic_green = pic_array[: , : , 2]

# %%
plt.imshow(pic_red)

# %%
plt.imshow(pic_blue)

# %%
plt.imshow(pic_green)

# %% [markdown]
# ### Yukarıda bakıyosun ve görüyosunuz ki red renkler yok sadece neden hala pic redin 1 inde 2 sinde indexleri var bunları sıfırlarsan pure red tarzı gozukur ama onden once cmap gray scale collor map i göstericem

# %%
plt.imshow(pic_red,cmap="gray")

# %%
# now im cleaning the left colors(green ,blue)
pic_arr2 = pic_array.copy()
pic_arr2[: , : ,1]= 0
pic_arr2[: , : ,2]= 0

# %%
plt.imshow(pic_arr2)

# %% [markdown]
# ## Gordugun gibi şimdi gırmızıııı
