# %% [markdown]
# ### My tasks
#
# #### ->input image larını yükle
#
# #### ->resimlerde yüzü detect et
#
# #### ->mask detectorümüzü uygula ve sınıflandır with mask mı without mask mı

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# import the necessary packages
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
from imutils.video import VideoStream
import numpy as np
import argparse
import imutils
import time
import cv2
import os

# %%
image1 =plt.imread("Project-MAİN/Örnek Resimler/kobe.jpg")
plt.imshow(image1)

# %%
image2 = plt.imread("Project-MAİN/Örnek Resimler/maske1.jpg")
plt.imshow(image2)

# %% [markdown]
# #### args =
# ###### --image: The path to the input image containing faces for inference
# ###### --face: The path to the face detector model directory (we need to localize faces prior to classifying them)
# ###### --model: The path to the face mask detector model that we trained earlier in this tutorial
# ###### --confidence: An optional probability threshold can be set to override 50% to filter weak face detection

# %%
###Load face detector
import os

# %%
prototxtPath = os.path.sep.join(["face_detector", "deploy.prototxt"])
weightsPath = os.path.sep.join(["face_detector" , "model.caffemodell"])
net = cv2.dnn.readNet(prototxtPath, weightsPath)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-1e3ef7abf395> in <module>
# ----> 1 net = cv2.dnn.readNet("Project-MAİN/face_detector/deploy.prototxt", "Project-MAİN/face_detector/model.caffemodel")
#       2
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\dnn\src\caffe\caffe_io.cpp:1121: error: (-2:Unspecified error) FAILED: fs.is_open(). Can't open "Project-MAİN/face_detector/deploy.prototxt" in function 'cv::dnn::ReadProtoFromTextFile'

# %%
prototxtPath
# Out:
# 'Project-MAİN/face_detector\\mertasd.txt'

# %%
weightsPath
# Out:
# 'Project-MAİN/face_detector\\model.caffemodel'
