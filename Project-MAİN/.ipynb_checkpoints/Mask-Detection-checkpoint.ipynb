# %%
## START WİTH MODEL
import numpy as np
import matplotlib.pyplot as plt
from imutils import paths

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\MERT\\Desktop\\MERT -OPENCV'

# %%
def display_img(img):
    plt.imshow(img, clim=(0.064, 0.068))

# %%
mask_example = plt.imread("Mask_Datasets2/Train/Mask/3.PNG")
display_img(mask_example)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f090c71e1656> in <module>
# ----> 1 mask_example = plt.imread("Mask_Datasets2/Train/Mask/3.PNG")
#       2 display_img(mask_example)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2133 @docstring.copy(matplotlib.image.imread)
#    2134 def imread(fname, format=None):
# -> 2135     return matplotlib.image.imread(fname, format)
#    2136
#    2137
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1431             return handler(fd)
#    1432         else:
# -> 1433             with open(fname, 'rb') as fd:
#    1434                 return handler(fd)
#    1435     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Mask_Datasets2/Train/Mask/3.PNG'

# %%
no_mask_example = plt.imread("Mask_Datasets2/Train/No_mask/15405.png")
display_img(no_mask_example)

# %%
no_mask_example.shape
# Out:
# (1024, 1024, 3)

# %%
mask_example.shape
# Out:
# (224, 189, 4)

# %% [markdown]
# ### AS you can see merto there are different sizes.

# %%
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img

imagePaths = list(paths.list_images("Mask_Datasets2"))
data = []  # X
labels = [] # y 

for imagePath in imagePaths:
        # extract the class label from the filename
        label = imagePath.split(os.path.sep)[-2]
        # load the input image (224x224) and preprocess it
        image = load_img(imagePath, target_size=(224, 224))
        image = img_to_array(image)
        image = preprocess_input(image)
        # update the data and labels lists, respectively
        data.append(image)
        labels.append(label)

# %%
data = np.array(data, dtype="float32")
labels = np.array(labels)

# %%
plt.imshow(data[1])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Labellar için one hot encoding

# %%
from sklearn import preprocessing
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
lb = preprocessing.LabelBinarizer()

labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# %%
labels.shape
# Out:
# (1100, 2)

# %% [markdown]
# ### Splitting the data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(data , labels , test_size = 0.20 , random_state = 7)

# %% [markdown]
# ### Data augmentation için

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=30, # rotate the image 30 degrees
                               width_shift_range=0.1, # Shift the pic width by a max of 10%
                               height_shift_range=0.1, # Shift the pic height by a max of 10%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.2, # Shear means cutting away part of the image (max 20%)
                               zoom_range=0.2, # Zoom in by 20% max
                               horizontal_flip=True, # Allo horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %% [markdown]
# ### IMAGE NET
#
# -> mobilenetv2 -fine tuning
#
# 1-önceden eğitilmiş Imagenet Weightsleriyle load etcem  ama networkun başındaki Ful coneccted layerleri nı keserek
#
# 2-yeni fully connected layer oluşturup onu eklicem
#
# 3-networkun base leyerslarını dondurcaz ,weightler backpropagation sırasında güncelenmicek  ama headlayers lar tune edilmiş olıcak .Amacımız buydu zaten

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

# %%
baseModel = MobileNetV2(weights="imagenet", include_top=False,input_tensor=Input(shape=(224, 224, 3)))

headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

model = Model(inputs=baseModel.input, outputs=headModel)


for layer in baseModel.layers:
    layer.trainable = False
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\keras_applications\mobilenet_v2.py:294: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Downloading data from https://github.com/JonathanCMitchell/mobilenet_v2_keras/releases/download/v1.1/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 6s 1us/step

# %% [markdown]
# ### ŞİMDİ HEAD OF NETWORK U TRAİN EDİCEZ TUNE ETMİŞTİK

# %%
from tensorflow.keras.optimizers import Adam

# %%
INIT_LR = 1e-4
EPOCHS = 20
BS = 32


initial_lr = 1e-4
epochs = 25
batch_size =32

opt = Adam(lr=initial_lr, decay=initial_lr / epochs)
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])

H = model.fit(
    image_gen.flow(x_train, y_train , batch_size=batch_size),
    steps_per_epoch=len(x_train) // BS,
    validation_data=(x_test, y_test),
    validation_steps=len(x_test) // BS,
    epochs=epochs)
# Out:
# Train for 27 steps, validate on 220 samples
# Epoch 1/25
# 27/27 [==============================] - 45s 2s/step - loss: 0.7086 - accuracy: 0.6120 - val_loss: 0.6082 - val_accuracy: 0.5938
# Epoch 2/25
# 27/27 [==============================] - 42s 2s/step - loss: 0.4484 - accuracy: 0.7925 - val_loss: 0.5431 - val_accuracy: 0.6406
# Epoch 3/25
# 27/27 [==============================] - 41s 2s/step - loss: 0.3628 - accuracy: 0.8455 - val_loss: 0.4675 - val_accuracy: 0.6927
# Epoch 4/25
# 27/27 [==============================] - 41s 2s/step - loss: 0.2979 - accuracy: 0.8821 - val_loss: 0.3931 - val_accuracy: 0.7656
# Epoch 5/25
# 27/27 [==============================] - 42s 2s/step - loss: 0.2388 - accuracy: 0.9151 - val_loss: 0.3624 - val_accuracy: 0.7812
# Epoch 6/25
# 27/27 [==============================] - 42s 2s/step - loss: 0.2154 - accuracy: 0.9116 - val_loss: 0.3406 - val_accuracy: 0.8021
# Epoch 7/25
# 27/27 [==============================] - 42s 2s/step - loss: 0.1956 - accuracy: 0.9292 - val_loss: 0.3105 - val_accuracy: 0.8333
# Epoch 8/25
# 27/27 [==============================] - 41s 2s/step - loss: 0.1937 - accuracy: 0.9328 - val_loss: 0.2949 - val_accuracy: 0.8438
# Epoch 9/25
# 27/27 [==============================] - 40s 1s/step - loss: 0.1753 - accuracy: 0.9304 - val_loss: 0.2749 - val_accuracy: 0.8594
# Epoch 10/25
# 27/27 [==============================] - 40s 1s/step - loss: 0.1489 - accuracy: 0.9505 - val_loss: 0.2299 - val_accuracy: 0.8906
# Epoch 11/25
# 27/27 [==============================] - 40s 1s/step - loss: 0.1617 - accuracy: 0.9328 - val_loss: 0.2210 - val_accuracy: 0.8958
# Epoch 12/25
# 27/27 [==============================] - 41s 2s/step - loss: 0.1232 - accuracy: 0.9583 - val_loss: 0.2211 - val_accuracy: 0.8906
# Epoch 13/25
# 27/27 [==============================] - 41s 2s/step - loss: 0.1170 - accuracy: 0.9564 - val_loss: 0.2156 - val_accuracy: 0.8958
# Epoch 14/25
# 27/27 [==============================] - 40s 1s/step - loss: 0.1358 - accuracy: 0.9446 - val_loss: 0.1905 - val_accuracy: 0.9062
# Epoch 15/25
# 27/27 [==============================] - 41s 2s/step - loss: 0.1232 - accuracy: 0.9481 - val_loss: 0.2178 - val_accuracy: 0.8854
# Epoch 16/25
# 27/27 [==============================] - 41s 2s/step - loss: 0.1306 - accuracy: 0.9481 - val_loss: 0.1854 - val_accuracy: 0.9167
# Epoch 17/25
# 27/27 [==============================] - 40s 1s/step - loss: 0.1095 - accuracy: 0.9623 - val_loss: 0.1834 - val_accuracy: 0.9115
# Epoch 18/25
# 27/27 [==============================] - 40s 1s/step - loss: 0.1029 - accuracy: 0.9564 - val_loss: 0.2458 - val_accuracy: 0.8542
# Epoch 19/25
# 27/27 [==============================] - 40s 1s/step - loss: 0.1264 - accuracy: 0.9517 - val_loss: 0.1578 - val_accuracy: 0.9167
# Epoch 20/25
# 27/27 [==============================] - 40s 1s/step - loss: 0.1021 - accuracy: 0.9611 - val_loss: 0.1738 - val_accuracy: 0.9167
# Epoch 21/25
# 27/27 [==============================] - 40s 1s/step - loss: 0.1023 - accuracy: 0.9646 - val_loss: 0.1736 - val_accuracy: 0.9167
# Epoch 22/25
# 27/27 [==============================] - 40s 1s/step - loss: 0.1109 - accuracy: 0.9552 - val_loss: 0.1619 - val_accuracy: 0.9167
# Epoch 23/25
# 27/27 [==============================] - 41s 2s/step - loss: 0.1101 - accuracy: 0.9587 - val_loss: 0.1368 - val_accuracy: 0.9427
# Epoch 24/25
# 27/27 [==============================] - 41s 2s/step - loss: 0.1092 - accuracy: 0.9599 - val_loss: 0.1808 - val_accuracy: 0.9062
# Epoch 25/25
# 27/27 [==============================] - 42s 2s/step - loss: 0.0892 - accuracy: 0.9717 - val_loss: 0.1642 - val_accuracy: 0.9115

# %%
from sklearn.metrics import classification_report ,accuracy_score

# %%
predict = model.predict(x_test , batch_size=batch_size)
predict = np.argmax(predict ,axis =1)

print(classification_report(y_test.argmax(axis =1) , predict , target_names =lb.classes_))
print()
# Out:
#               precision    recall  f1-score   support
#
#         Mask       0.86      0.97      0.91       103
#      No_mask       0.97      0.86      0.91       117
#
#     accuracy                           0.91       220
#    macro avg       0.92      0.92      0.91       220
# weighted avg       0.92      0.91      0.91       220
#
#
# 0.9136363636363637

# %%
print(accuracy_score(y_test.argmax(axis = 1 ) , predict))
# Out:
# 0.9136363636363637

# %%
model.save("training_model.h5")

# %%
N = epochs
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()
